# %%
! pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#                                               0.0/96.5 kB ? eta -:--:--
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
import pandas as pd
df=pd.read_excel('Sample - Superstore.xls')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
#Recency
df['Order Date']=pd.to_datetime(df['Order Date'])#converting to date time format
#recency for each customer
current_date=df['Order Date'].max()

recency_data=df.groupby('Customer ID')['Order Date'].max().reset_index()
recency_data['Recency']=(current_date-recency_data['Order Date']).dt.days
print(recency_data[['Customer ID','Recency']].head())
# Out:
#   Customer ID  Recency
# 0    AA-10315      184
# 1    AA-10375       19
# 2    AA-10480      259
# 3    AA-10645       55
# 4    AB-10015      415

# %%
#calculate frequency
frequency_data=df.groupby('Customer ID')['Order ID'].nunique().reset_index()
frequency_data.columns=['Customer ID','Frequency']

print(frequency_data.head())
# Out:
#   Customer ID  Frequency
# 0    AA-10315          5
# 1    AA-10375          9
# 2    AA-10480          4
# 3    AA-10645          6
# 4    AB-10015          3

# %%
#monetary value
df['TotalPrice']=df['Sales']*df['Quantity']

monetary_data=df.groupby('Customer ID')['TotalPrice'].sum().reset_index()
monetary_data.columns=['Customer ID','Monetary']
print(monetary_data.head())
# Out:
#   Customer ID   Monetary
# 0    AA-10315  16073.344
# 1    AA-10375   2734.830
# 2    AA-10480   5493.936
# 3    AA-10645  22927.855
# 4    AB-10015   1984.480

# %%
rfm_data=pd.merge(recency_data,frequency_data,on='Customer ID')
rfm_data=pd.merge(rfm_data,monetary_data,on='Customer ID')
rfm_data.drop('Order Date',axis=1)
# Out:
#     Customer ID  Recency  Frequency   Monetary
# 0      AA-10315      184          5  16073.344
# 1      AA-10375       19          9   2734.830
# 2      AA-10480      259          4   5493.936
# 3      AA-10645       55          6  22927.855
# 4      AB-10015      415          3   1984.480
# ..          ...      ...        ...        ...
# 788    XP-21865       43         11   8676.214
# 789    YC-21895        4          5  27208.926
# 790    YS-21880        9          8  46478.992
# 791    ZC-21910       54         13  40212.889
# 792    ZD-21925      202          5   6492.448
#
# [793 rows x 4 columns]

# %%
rfm_data['R_rank']=rfm_data['Recency'].rank(ascending=False)
rfm_data['F_rank']=rfm_data['Frequency'].rank(ascending=True)
rfm_data['M_rank']=rfm_data['Monetary'].rank(ascending=True)

#normalizing the rank of customers
rfm_data['R_rank_norm']=(rfm_data['R_rank']/rfm_data['R_rank'].max())*100
rfm_data['F_rank_norm']=(rfm_data['F_rank']/rfm_data['F_rank'].max())*100
rfm_data['M_rank_norm']=(rfm_data['M_rank']/rfm_data['M_rank'].max())*100
rfm_data.drop(columns=['R_rank','F_rank','M_rank'],inplace=True)
rfm_data.head(10)
# Out:
#   Customer ID  Recency  Frequency    Monetary  R_rank_norm  F_rank_norm  \
# 0    AA-10315      184          5   16073.344    24.699937    33.102144
# 1    AA-10375       19          9    2734.830    86.607707    84.489281
# 2    AA-10480      259          4    5493.936    17.687934    18.600252
# 3    AA-10645       55          6   22927.855    58.559697    48.297604
# 4    AB-10015      415          3    1984.480     9.033481     9.205549
# 5    AB-10060       54          8   35390.580    59.444093    74.842371
# 6    AB-10105       41         10  143857.709    67.214150    91.424968
# 7    AB-10150       41          5    3111.242    67.214150    33.102144
# 8    AB-10165       25          8    3625.514    81.301327    74.842371
# 9    AB-10255      166          9    2397.564    26.721415    84.489281
#
#    M_rank_norm
# 0    70.239596
# 1    14.249685
# 2    29.003783
# 3    81.210593
# 4    10.466583
# 5    91.929382
# 6    99.873897
# 7    15.889029
# 8    17.906683
# 9    12.862547

# %%
rfm_data['RFM_score']=0.15*rfm_data['R_rank_norm']+0.28*rfm_data['F_rank_norm']+0.57*rfm_data['M_rank_norm']
rfm_data['RFM_score']*=0.05
rfm_data=rfm_data.round(2)
rfm_data[['Customer ID','RFM_score']].head(7)
# Out:
#   Customer ID  RFM_score
# 0    AA-10315       2.65
# 1    AA-10375       2.24
# 2    AA-10480       1.22
# 3    AA-10645       3.43
# 4    AB-10015       0.50
# 5    AB-10060       4.11
# 6    AB-10105       4.63

# %%
import numpy as np
#rating customer based on RFM score
rfm_data['Customer_segment']=np.where(rfm_data['RFM_score']>4.5,'Top Customers',
                                    (np.where(rfm_data['RFM_score']>4,'high value customer',
                                    (np.where(rfm_data['RFM_score']>3,'medium value customer',
                                    (np.where(rfm_data['RFM_score']>1.5,'low value customer','lost customers')))))))
rfm_data[['Customer ID','RFM_score','Customer_segment']].head(20)
# Out:
#    Customer ID  RFM_score       Customer_segment
# 0     AA-10315       2.65     low value customer
# 1     AA-10375       2.24     low value customer
# 2     AA-10480       1.22         lost customers
# 3     AA-10645       3.43  medium value customer
# 4     AB-10015       0.50         lost customers
# 5     AB-10060       4.11    high value customer
# 6     AB-10105       4.63          Top Customers
# 7     AB-10150       1.42         lost customers
# 8     AB-10165       2.17     low value customer
# 9     AB-10255       1.75     low value customer
# 10    AB-10600       1.66     low value customer
# 11    AC-10420       0.72         lost customers
# 12    AC-10450       3.75  medium value customer
# 13    AC-10615       2.54     low value customer
# 14    AC-10660       0.83         lost customers
# 15    AD-10180       4.00  medium value customer
# 16    AF-10870       2.48     low value customer
# 17    AF-10885       1.03         lost customers
# 18    AG-10270       2.93     low value customer
# 19    AG-10300       0.68         lost customers

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.pie(rfm_data.Customer_segment.value_counts(),labels=rfm_data.Customer_segment.value_counts().index,autopct='%.0f%%')
plt.show()
