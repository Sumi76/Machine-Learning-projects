# %%
import pandas as pd
df=pd.read_csv('/content/TRAINING_.csv')
df
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 0        1          305    8.0        2.0          1.0         3.0   NO
# 1        2          344    6.0        7.0          7.0         8.0   no
# 2        3          294    8.0        4.0          3.0         4.0  yes
# 3        4          328    5.0        4.0          2.0         4.0   NO
# 4        5          295    9.0        5.0          3.0         5.0  NaN
# ...    ...          ...    ...        ...          ...         ...  ...
# 6995  6996          306    8.0        2.0          1.0         3.0  NaN
# 6996  6997          341    5.0        3.0          2.0         4.0  YES
# 6997  6998          306    6.0        4.0          2.0         4.0  yes
# 6998  6999          338    8.0        7.0          6.0         7.0   NO
# 6999  7000          314    5.0        6.0          4.0         6.0  yes
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB Grade EXPECTED
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# Area(total)       0
# Troom             2
# Nbedrooms         3
# Nbwashrooms       2
# Twashrooms        1
# roof           1353
# Roof(Area)     1353
# Lawn(Area)        2
# Nfloors           0
# API               1
# ANB               0
# Grade             0
# EXPECTED          0
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True)
df.fillna(df['roof'].mode()[0],inplace=True)
df
# Out:
# <ipython-input-4-97b21fec8cf3>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(),inplace=True)
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 0        1          305    8.0        2.0          1.0         3.0   NO
# 1        2          344    6.0        7.0          7.0         8.0   no
# 2        3          294    8.0        4.0          3.0         4.0  yes
# 3        4          328    5.0        4.0          2.0         4.0   NO
# 4        5          295    9.0        5.0          3.0         5.0   no
# ...    ...          ...    ...        ...          ...         ...  ...
# 6995  6996          306    8.0        2.0          1.0         3.0   no
# ...

# %%
df.drop_duplicates()
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 0        1          305    8.0        2.0          1.0         3.0   NO
# 1        2          344    6.0        7.0          7.0         8.0   no
# 2        3          294    8.0        4.0          3.0         4.0  yes
# 3        4          328    5.0        4.0          2.0         4.0   NO
# 4        5          295    9.0        5.0          3.0         5.0   no
# ...    ...          ...    ...        ...          ...         ...  ...
# 6995  6996          306    8.0        2.0          1.0         3.0   no
# 6996  6997          341    5.0        3.0          2.0         4.0  YES
# 6997  6998          306    6.0        4.0          2.0         4.0  yes
# 6998  6999          338    8.0        7.0          6.0         7.0   NO
# 6999  7000          314    5.0        6.0          4.0         6.0  yes
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB Grade EXPECTED
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df.corr()
# Out:
# <ipython-input-6-3aa5ed7cb7ff>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    id  Area(total)     Troom  Nbedrooms  Nbwashrooms  \
# id           1.000000     0.012421  0.015676  -0.014493    -0.012914
# Area(total)  0.012421     1.000000 -0.002463   0.002261     0.017777
# Troom        0.015676    -0.002463  1.000000   0.002899     0.011570
# Nbedrooms   -0.014493     0.002261  0.002899   1.000000     0.779157
# Nbwashrooms -0.012914     0.017777  0.011570   0.779157     1.000000
# Twashrooms  -0.008991     0.011123  0.013895   0.822156     0.949633
# Roof(Area)   0.001379     0.014079 -0.012729   0.007681     0.006676
# Lawn(Area)  -0.018359     0.009646  0.009573   0.010142     0.015162
# Nfloors     -0.017674     0.019886  0.005259   0.687964     0.707419
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-7-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# from the above heat map it is clear that nbwashrooms and twashrooms are correlated and n bedrooms and twashrooms are correlated

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3299 entries, 0 to 3298
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           3299 non-null   int64
#  1   Area(total)  3299 non-null   int64
#  2   Troom        3298 non-null   float64
#  3   Nbedrooms    3298 non-null   float64
#  4   Nbwashrooms  3298 non-null   float64
#  5   Twashrooms   3299 non-null   int64
#  6   roof         2646 non-null   object
#  7   Roof(Area)   2646 non-null   float64
#  8   Lawn(Area)   3298 non-null   float64
#  9   Nfloors      3299 non-null   int64
#  10  API          3298 non-null   float64
#  11  ANB          3299 non-null   int64
#  12  EXPECTED     3299 non-null   object
# dtypes: float64(6), int64(5), object(2)
# memory usage: 335.2+ KB

# %%
df['EXPECTED']= df['EXPECTED'].str.replace('$', '')
df['EXPECTED']=df['EXPECTED'].astype(int)
# Out:
# <ipython-input-11-b1360d5e9e11>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['EXPECTED']= df['EXPECTED'].str.replace('$', '')

# %%
dft['EXPECTED']= dft['EXPECTED'].str.replace('$', '')
dft['EXPECTED']=dft['EXPECTED'].astype(int)
# Out:
# <ipython-input-12-ad7a109db868>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dft['EXPECTED']= dft['EXPECTED'].str.replace('$', '')

# %%
sns.scatterplot(data=df,x=df['Nbwashrooms'],y=df['Twashrooms'])
# Out:
# <Axes: xlabel='Nbwashrooms', ylabel='Twashrooms'>

# %%
sns.scatterplot(data=df,x=df['Nbedrooms'],y=df['Twashrooms'])
# Out:
# <Axes: xlabel='Nbedrooms', ylabel='Twashrooms'>

# %%
B=df.drop(['roof','Grade'],axis=1)
A=df['Grade']
plt.figure(figsize=(20,40))
for i,col in enumerate(B,1):
  plt.subplot(6,2,i)
  sns.barplot(data=df,x=A,y=col)
  plt.xlabel('Grade')
  plt.ylabel(col)
plt.show()

# %%
dft=pd.read_csv('/content/TEST_.csv')
dft
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 0        1          348    9.0        5.0          3.0           5  NaN
# 1        2          311    6.0        5.0          5.0           6   NO
# 2        3          342    5.0        6.0          6.0           7  yes
# 3        4          329    7.0        7.0          4.0           6  NaN
# 4        5          307    6.0        2.0          3.0           4   no
# ...    ...          ...    ...        ...          ...         ...  ...
# 3294  3295          349    7.0        3.0          3.0           4  NaN
# 3295  3296          338    7.0        3.0          2.0           4   NO
# 3296  3297          307    8.0        4.0          5.0           6  yes
# 3297  3298          352    5.0        3.0          4.0           5  YES
# 3298  3299          329    5.0        3.0          1.0           3  yes
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB EXPECTED
# ...

# %%
dft.isnull().sum()
# Out:
# id               0
# Area(total)      0
# Troom            1
# Nbedrooms        1
# Nbwashrooms      1
# Twashrooms       0
# roof           653
# Roof(Area)     653
# Lawn(Area)       1
# Nfloors          0
# API              1
# ANB              0
# EXPECTED         0
# dtype: int64

# %%
dft.fillna(dft.mean(),inplace=True)
dft.fillna(dft['roof'].mode()[0],inplace=True)
dft
# Out:
# <ipython-input-13-9e4b08e19e0a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dft.fillna(dft.mean(),inplace=True)
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 0        1          348    9.0        5.0          3.0           5   NO
# 1        2          311    6.0        5.0          5.0           6   NO
# 2        3          342    5.0        6.0          6.0           7  yes
# 3        4          329    7.0        7.0          4.0           6   NO
# 4        5          307    6.0        2.0          3.0           4   no
# ...    ...          ...    ...        ...          ...         ...  ...
# 3294  3295          349    7.0        3.0          3.0           4   NO
# ...

# %% [markdown]
# **logistic regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler

train_data=df
test_data=dft

x_train=df.drop(['Grade','id'],axis=1)
y_train=df['Grade']
x_test=dft
X_train=pd.get_dummies(x_train,drop_first=True)


#x=pd.get_dummies(x,drop_first=True)

X_train,x_test,y_train,y_test=train_test_split(X_train,y_train,test_size=0.2,random_state=100)

model=LogisticRegression()
model.fit(X_train,y_train)
predictions=model.predict(x_test)


lr_accuracy=accuracy_score(y_test,predictions)
conf_matrix=confusion_matrix(y_test,predictions)
class_report=classification_report(y_test,predictions)

print("accuracy:",lr_accuracy)
print("confusion matrix:\n",conf_matrix)
print('classification report:\n',class_report)
# Out:
# accuracy: 0.59
# confusion matrix:
#  [[ 31  59   9   0   0]
#  [ 17 130 115   2   0]
#  [  2  85 403 126   0]
#  [  0   3 149 262   0]
#  [  0   0   2   5   0]]
# classification report:
#                precision    recall  f1-score   support
#
#            A       0.62      0.31      0.42        99
#            B       0.47      0.49      0.48       264
#            C       0.59      0.65      0.62       616
#            D       0.66      0.63      0.65       414
#            E       0.00      0.00      0.00         7
#
#     accuracy                           0.59      1400
#    macro avg       0.47      0.42      0.43      1400
# weighted avg       0.59      0.59      0.59      1400
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %% [markdown]
# **DECISION TREE**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
train_data=df
test_data=dft

x_train=df.drop(['Grade','id'],axis=1)
y_train=df['Grade']
x_test=dft
X_train=pd.get_dummies(x_train,drop_first=True)

X_train,x_test,y_train,y_test=train_test_split(X_train,y_train,train_size=0.8,random_state=100)

clf=DecisionTreeClassifier()
clf.fit(X_train,y_train)
y_pred=clf.predict(x_test)

scaler=StandardScaler()
x_train=scaler.fit_transform(X_train)
x_test=scaler.fit_transform(x_test)

acccuracy=accuracy_score(y_test,y_pred)
conf_matrix=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)
print('accuracy:',acccuracy)
print('confusion matrix:\n',conf_matrix)
print('classification report:\n',class_report)
# Out:
# accuracy: 0.7985714285714286
# confusion matrix:
#  [[ 74  24   1   0   0]
#  [ 25 194  44   1   0]
#  [  2  62 486  66   0]
#  [  0   0  50 360   4]
#  [  0   0   0   3   4]]
# classification report:
#                precision    recall  f1-score   support
#
#            A       0.73      0.75      0.74        99
#            B       0.69      0.73      0.71       264
#            C       0.84      0.79      0.81       616
#            D       0.84      0.87      0.85       414
#            E       0.50      0.57      0.53         7
#
#     accuracy                           0.80      1400
#    macro avg       0.72      0.74      0.73      1400
# weighted avg       0.80      0.80      0.80      1400

# %% [markdown]
# **random forest**

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest=RandomForestClassifier(random_state=100)
random_forest.fit(X_train,y_train)

y_pred_rf=random_forest.predict(x_test)
accuracy_rf=accuracy_score(y_test,y_pred_rf)
print('random forest accuracy:',accuracy_rf)
# Out:
# random forest accuracy: 0.8842857142857142

# %%
rf_classifier=RandomForestClassifier(random_state=8)
from sklearn.model_selection import GridSearchCV

#define the  hyperparameter grid search
param_grid={
    'n_estimators':[10,20,30],
    'max_depth':[10,20,30],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4]
}
grid_search=GridSearchCV(estimator=rf_classifier,param_grid=param_grid,cv=5)
grid_search.fit(X_train,y_train)
best_params=grid_search.best_params_
best_rf_classifier=grid_search.best_estimator_

print('best parameters:',best_params)
test_accuracy=best_rf_classifier.score(x_test,y_test)
print('test accuracy:',test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6917ba9caa8b> in <cell line: 1>()
# ----> 1 rf_classifier=RandomForestClassifier(random_state=8)
#       2 from sklearn.model_selection import GridSearchCV
#       3
#       4 #define the  hyperparameter grid search
#       5 param_grid={
#
# NameError: name 'RandomForestClassifier' is not defined

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_classifier=KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train,y_train)
ypred=knn_classifier.predict(x_test)

accuracy_knn=accuracy_score(y_test,ypred)
conf_matrix=confusion_matrix(y_test,ypred)
class_report=classification_report(y_test,ypred)
print('accuracy:',accuracy_knn)
print('confusion matrix:\n',conf_matrix)
print('classification report:\n',class_report)
# Out:
# accuracy: 0.6192857142857143
# confusion matrix:
#  [[ 55  38   6   0   0]
#  [ 27 144  92   1   0]
#  [  1 104 378 133   0]
#  [  0   4 121 288   1]
#  [  0   0   0   5   2]]
# classification report:
#                precision    recall  f1-score   support
#
#            A       0.66      0.56      0.60        99
#            B       0.50      0.55      0.52       264
#            C       0.63      0.61      0.62       616
#            D       0.67      0.70      0.68       414
#            E       0.67      0.29      0.40         7
#
#     accuracy                           0.62      1400
#    macro avg       0.63      0.54      0.57      1400
# weighted avg       0.62      0.62      0.62      1400

# %% [markdown]
# **SVM**

# %%
dft.shape
# Out:
# (3299, 13)

# %%
from sklearn.svm import SVC

train_data=df
test_data=dft

x_train=df.drop('Grade',axis=1)
y_train=df['Grade']
x_test=dft
X_train=pd.get_dummies(x_train,drop_first=True)

X_train,x_test,y_train,y_test=train_test_split(X_train,y_train,train_size=0.8,random_state=42)

classifier=SVC(kernel='linear',decision_function_shape='ovr')
classifier.fit(X_train,y_train)
ySV_pred=classifier.predict(x_test)

accuracy=accuracy_score(y_test,ySV_pred)
conf_matrix=confusion_matrix(y_test,ySV_pred)
class_report=classification_report(y_test,ySV_pred)

print("accuracy:",accuracy)
print("confusion matrix:\n",conf_matrix)
print('classification report:\n',class_report)
# Out:
# accuracy: 0.8964285714285715
# confusion matrix:
#  [[ 76  18   0   0   0]
#  [  4 262  30   0   0]
#  [  0  26 530  30   0]
#  [  0   0  33 386   0]
#  [  0   0   1   3   1]]
# classification report:
#                precision    recall  f1-score   support
#
#            A       0.95      0.81      0.87        94
#            B       0.86      0.89      0.87       296
#            C       0.89      0.90      0.90       586
#            D       0.92      0.92      0.92       419
#            E       1.00      0.20      0.33         5
#
#     accuracy                           0.90      1400
#    macro avg       0.92      0.74      0.78      1400
# weighted avg       0.90      0.90      0.90      1400

# %%
x1=['logistic_reg','decision_tree','Random_forest','KNN','SVC']
y1=[lr_accuracy,acccuracy,accuracy_rf,accuracy_rf,accuracy]
plt.bar(x1,y1)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# from the above bar plot we can understand that svm algorith has the highest accuracy so we use svm model to pedict the new data

# %%
new_data=dft
new_Data=pd.get_dummies(dft,drop_first=True)
predictions = classifier.predict(new_Data)

# %%
predictions_df = pd.DataFrame({'id': new_Data['id'], 'Grade': predictions})
predictions_df.to_csv('predictions1.csv', index=False)
